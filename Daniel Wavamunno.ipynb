# %% [markdown]
# ## Daniel Wavamunno         -      S23B23/091

# %%
import pandas as pd

flood =pd.read_csv("flood.csv")
flood.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
# ...

# %%
flood.isnull().sum()
# Out:
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
flood.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
flood.drop_duplicates()
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                     3                   8                6              6
# 1                     8                   4                5              7
# 2                     3                  10                4              1
# 3                     4                   4                2              7
# 4                     3                   7                5              2
# ...                 ...                 ...              ...            ...
# 49995                 3                   7                4              7
# 49996                 3                  10                3              8
# 49997                 4                   4                5              7
# 49998                 4                   5                4              4
# 49999                 4                   5                6              3
#
# ...

# %%
flood.corr()
# Out:
#                                  MonsoonIntensity  TopographyDrainage  \
# MonsoonIntensity                         1.000000           -0.003470
# TopographyDrainage                      -0.003470            1.000000
# RiverManagement                          0.002247            0.002492
# Deforestation                           -0.005384            0.002046
# Urbanization                             0.005092            0.000116
# ClimateChange                            0.005959           -0.002288
# DamsQuality                              0.002790           -0.004472
# Siltation                               -0.003191            0.010675
# AgriculturalPractices                    0.002723           -0.004550
# Encroachments                           -0.003723           -0.007272
# IneffectiveDisasterPreparedness          0.002358            0.001328
# DrainageSystems                         -0.000118           -0.001608
# ...

# %%
flood.columns
# Out:
# Index(['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
flood['target'] = flood.FloodProbability

x = flood[['MonsoonIntensity','TopographyDrainage','RiverManagement','Deforestation','Urbanization','ClimateChange','DamsQuality',
           'Siltation','AgriculturalPractices','Encroachments','IneffectiveDisasterPreparedness','DrainageSystems','CoastalVulnerability',
           'Landslides','Watersheds','DeterioratingInfrastructure','PopulationScore','WetlandLoss','InadequatePlanning','PoliticalFactors']]
y = flood['target']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 42)

# %%
## Support Vector Regressor
from sklearn.svm import SVR

model=SVR()
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,root_mean_squared_error

correlation_score = r2_score(y_test,y_pred)
rms_error = root_mean_squared_error(y_test,y_pred)

# %%
print(f'correlation score (R2_values) : {correlation_score}\n')
print(f"Error: {rms_error} \n")
# Out:
# correlation score (R2_values) : 0.7200938781158139
#
# Error: 0.026403223226589282

# %%
## Decison Tree Regressor
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,root_mean_squared_error

correlation_score = r2_score(y_test,y_pred)

# %%
print(f'correlation score (R2_values) : {correlation_score}\n')
# Out:
# correlation score (R2_values) : 0.10163703232672527

# %%
## Linear Regression
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = root_mean_squared_error(y_test,y_pred)
correlation_score = r2_score(y_test, y_pred)

print(f"R² score : {correlation_score}\n Mean Squared Error  : {mse}")
# Out:
# R² score : 1.0
#  Mean Squared Error  : 3.3256368872860575e-16

# %% [markdown]
# ## Hyper Parameter for 'Tuning Support Vector Regressor' and 'Decision Tree Regressor'

# %%
from sklearn.model_selection import GridSearchCV


param_grid = {
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : [2, 5, 10],
    'min_samples_leaf' : [1, 2, 5],
    'criterion' : ['absolute_error','squared_error','poisson','friedman_mse']
}

grid_search = GridSearchCV(
    estimator = DecisionTreeRegressor(random_state=42),
    param_grid = param_grid,
    scoring = 'neg_mean_squared_error',
    cv = 5,
    n_jobs = -1
)

# %%
grid_search.fit(x_train, y_train)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2}

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Initialize the model
dtr = DecisionTreeRegressor(
    criterion='squared_error',
    max_depth=10,
    min_samples_leaf=5,
    min_samples_split=2
)

# Fit the model
dtr.fit(x_train, y_train)

# Make predictions
y_pred = dtr.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)  # Renamed to 'r2' to avoid conflict

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))  # Use mean_squared_error with sqrt for RMSE

print("R^2 Score:", r2)
print("Root Mean Squared Error:", rmse)
# Out:
# R^2 Score: 0.23308996485198374
# Root Mean Squared Error: 0.04370417829313875

# %% [markdown]
# ## SVR hyper parameter tuning

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for SVR
param_grid = {
    'C': [0.1, 1, 10, 100],              # Regularization parameter
    'epsilon': [0.1, 0.2, 0.5, 1],       # Epsilon in the epsilon-SVR model
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # Kernel types
    'degree': [2, 3, 4]                  # Degree of the polynomial kernel (only applies if kernel='poly')
}

# Set up GridSearchCV with SVR
grid_search = GridSearchCV(
    estimator=SVR(),
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=5,
    n_jobs=-1
)

# %%
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
# Out:
# C:\Users\danlw\AppData\Roaming\Python\Python312\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5, 1],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='neg_mean_squared_error')

# %%
# best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score (neg MSE):", best_score)
# Out:
# Best Parameters: {'C': 0.1, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}
# Best Score (neg MSE): -0.000733550931204797

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Get the best parameters from the grid search
best_params = grid_search.best_params_

# Initialize SVR with the best parameters
best_svr = SVR(**best_params)

# Fit the model to the training data
best_svr.fit(x_train, y_train)

# Make predictions on the test data
y_pred = best_svr.predict(x_test)

# Calculate R² score
r2 = r2_score(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R² Score:", r2)
print("Root Mean Squared Error:", rmse)
# Out:
# R² Score: 0.7354095767968614
# Root Mean Squared Error: 0.025670705794008007
